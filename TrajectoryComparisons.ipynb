# %% [markdown]
# ## EM-APEX & ARGO Comparisons: Trajectory & Dates

# %% [markdown]
# ### First Investigation - Which floats have the same trajectory or at least launching position?

# %% [markdown]
# #### SMILE:

# %%
import xarray as xr
xr.set_options(display_style="html", display_expand_attrs=False);
from matplotlib import pyplot as plt
plt.style.use('default')
import cartopy
import cartopy.crs as ccrs
import argopy

# %%
from argopy import DataFetcher as ArgoDataFetcher
argo_loader = ArgoDataFetcher(src='argovis', parallel=True)
argo_loader
# Out:
# <datafetcher.argovis> 'No access point initialised'
# Available access points: float, profile, region
# Performances: cache=False, parallel=True
# User mode: standard
# Dataset: phy

# %%
help(argo_loader.region)
# Out:
# Help on method region in module argopy.fetchers:
#
# region(*args) method of argopy.fetchers.ArgoDataFetcher instance
#     Space/time domain data fetcher
#
#     Parameters
#     ----------
#     box: list()
#         Define the domain to load Argo data for. The box list is made of:
#             - lon_min: float, lon_max: float,
#             - lat_min: float, lat_max: float,
#             - dpt_min: float, dpt_max: float,
#             - date_min: str (optional), date_max: str (optional)
#
#         Longitude, latitude and pressure bounds are required, while the two bounding dates are optional.
#         If bounding dates are not specified, the entire time series is fetched.
#         Eg: [-60, -55, 40., 45., 0., 10., '2007-08-01', '2007-09-01']
#
#     Returns
#     -------
#     :class:`argopy.fetchers.ArgoDataFetcher`
#         A data source fetcher for a space/time domain

# %%
#argo_loader.region([-147, -138, 24, 36, 0, 10000, '1999-01-01', '2023-01-01']).load() 
#argo_loader
#argo_loader.plot('trajectory', set_global=True)

# %%
argo_loader.region([-147, -138, 24, 36, 0, 10000]).load() 
argo_loader
argo_loader.plot('trajectory', set_global=True)
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# (<Figure size 900x540 with 1 Axes>,
#  <GeoAxes: xlabel='longitude', ylabel='latitude'>)

# %%
apDS = argo_loader.float([4902149]).load().data
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 248617)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 248613 248614 248615 248616
#     TIME             (N_POINTS) datetime64[ns] 2014-10-22T20:17:38.990000 ......
#     LATITUDE         (N_POINTS) float64 28.66 28.66 28.66 ... 34.29 34.29 34.29
# ...

# %%
#SPECIAL FOCUS, although this one was just testing out some of the floats I found beyond that one the computer found.

# %%
apDS = argo_loader.float(5901468).load().data
apDS
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# (<Figure size 900x540 with 1 Axes>,
#  <GeoAxes: xlabel='longitude', ylabel='latitude'>)

# %%
apDS = argo_loader.float(5903385).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 145951)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 145947 145948 145949 145950
#     TIME             (N_POINTS) datetime64[ns] 2011-01-10T18:22:15 ... 2015-0...
#     LATITUDE         (N_POINTS) float64 22.7 22.7 22.7 ... 25.07 25.07 25.07
# ...

# %% [markdown]
# ##### These are the floats I hand-picked based on this [website](https://fleetmonitoring.euro-argo.eu/dashboard?Status=Active,Inactive&Basin=PACIFIC%20OCEAN)

# %%
apDS = argo_loader.float([5901468, 5903385, 3901156, 5903741, 5904128, 5900639, 5906520, 4903012, 4900816, 4900276, 5903608]).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 777876)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 777872 777873 777874 777875
#     TIME             (N_POINTS) datetime64[ns] 2002-09-25T14:02:49 ... 2023-0...
#     LATITUDE         (N_POINTS) float64 38.17 38.17 38.17 ... 29.75 29.75 29.75
# ...

# %% [markdown]
# ##### Special Focus (this one and all future ones focus on particular floats that both the computer AND I hand-picked.)
# Parameters of Consideration:
# 1. Picked floats on both computer & personal picks
# 2. Picked one float for each relative position (3 total)
# 3. Picked one float that was relatively new, date-wise, and then one float that was older (for time comparisons!)

# %%
apDS = argo_loader.float(4903012).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 160408)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 160404 160405 160406 160407
#     TIME             (N_POINTS) datetime64[ns] 2019-03-24T06:56:28.600000 ......
#     LATITUDE         (N_POINTS) float64 30.8 30.8 30.8 ... 35.11 35.11 35.11
# ...

# %%
apDS = argo_loader.float(5906520).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 18803)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 18799 18800 18801 18802
#     TIME             (N_POINTS) datetime64[ns] 2022-06-27T01:46:08 ... 2023-0...
#     LATITUDE         (N_POINTS) float64 29.97 29.97 29.97 ... 29.75 29.75 29.75
#     LONGITUDE        (N_POINTS) float64 -145.1 -145.1 -145.1 ... -145.6 -145.6
# ...

# %%
apDS = argo_loader.float(5900639).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 15741)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 15737 15738 15739 15740
#     TIME             (N_POINTS) datetime64[ns] 2004-08-26T07:29:01.990000 ......
#     LATITUDE         (N_POINTS) float64 29.88 29.88 29.88 ... 30.28 30.28 30.28
#     LONGITUDE        (N_POINTS) float64 -140.7 -140.7 -140.7 ... -145.0 -145.0
# ...

# %%
apDS = argo_loader.float(4900816).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 24981)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 24977 24978 24979 24980
#     TIME             (N_POINTS) datetime64[ns] 2007-05-25T22:59:10 ... 2017-0...
#     LATITUDE         (N_POINTS) float64 39.29 39.29 39.29 ... 34.54 34.54 34.54
#     LONGITUDE        (N_POINTS) float64 -126.3 -126.3 -126.3 ... -139.6 -139.6
# ...

# %%
apDS = argo_loader.float(5901468).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 116635)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 116631 116632 116633 116634
#     TIME             (N_POINTS) datetime64[ns] 2007-12-23T10:58:55.990000 ......
#     LATITUDE         (N_POINTS) float64 22.87 22.87 22.87 ... 25.46 25.46 25.46
# ...

# %%
apDS = argo_loader.float(5903741).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 128539)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 128535 128536 128537 128538
#     TIME             (N_POINTS) datetime64[ns] 2012-03-27T14:11:09.990000 ......
#     LATITUDE         (N_POINTS) float64 22.68 22.68 22.68 ... 25.09 25.09 25.09
# ...

# %% [markdown]
# #### This is the data provided given the bounding box on the website (more floats provided basically):

# %% [markdown]
# #### DIMES

# %%
argo_loader.region([-78, -49, -61, -51, 0, 10000]).load()
argo_loader
argo_loader.plot('trajectory', set_global=True)
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# (<Figure size 900x540 with 1 Axes>,
#  <GeoAxes: xlabel='longitude', ylabel='latitude'>)

# %% [markdown]
# ##### These are the floats I hand-picked based on this [website](https://fleetmonitoring.euro-argo.eu/dashboard?Status=Active,Inactive&Basin=PACIFIC%20OCEAN)

# %%
apDS = argo_loader.float([7900308, 5903509, 7900062, 5900900, 5905267, 5900339, 5900340, 6990502, 5905279, 3900991, 1901575]).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 754144)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 754140 754141 754142 754143
#     TIME             (N_POINTS) datetime64[ns] 2005-02-21T13:57:54 ... 2023-0...
#     LATITUDE         (N_POINTS) float64 -58.19 -58.19 -58.19 ... -52.22 -52.22
# ...

# %%
#Special Cases (both suggested by computer & my own analysis)

# %%
apDS = argo_loader.float(5905267).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 211303)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 211299 211300 211301 211302
#     TIME             (N_POINTS) datetime64[ns] 2017-10-26T20:00:55.870000 ......
#     LATITUDE         (N_POINTS) float64 -43.5 -43.5 -43.5 ... -57.25 -57.25
# ...

# %%
apDS = argo_loader.float(6990502).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 8314)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 5 ... 8309 8310 8311 8312 8313
#     TIME             (N_POINTS) datetime64[ns] 2023-02-22T05:41:30 ... 2023-0...
#     LATITUDE         (N_POINTS) float64 -59.83 -59.83 -59.83 ... -60.17 -60.17
# ...

# %%
apDS = argo_loader.float(5905279).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 206227)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 206223 206224 206225 206226
#     TIME             (N_POINTS) datetime64[ns] 2018-02-12T14:13:26.680000 ......
#     LATITUDE         (N_POINTS) float64 -56.5 -56.5 -56.5 ... -52.22 -52.22
#     LONGITUDE        (N_POINTS) float64 174.2 174.2 174.2 ... -54.99 -54.99
# ...

# %% [markdown]
# #### NISKINE:

# %%
argo_loader.region([-24, -20, 56, 59, 0, 10000]).load()
argo_loader
argo_loader.plot('trajectory', set_global=True)
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# (<Figure size 900x540 with 1 Axes>,
#  <GeoAxes: xlabel='longitude', ylabel='latitude'>)

# %% [markdown]
# ##### These are the floats I hand-picked based on this [website](https://fleetmonitoring.euro-argo.eu/dashboard?Status=Active,Inactive&Basin=PACIFIC%20OCEAN)

# %%
apDS = argo_loader.float([6901180, 7900572, 3901871, 6904191]).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 430683)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 430679 430680 430681 430682
#     TIME             (N_POINTS) datetime64[ns] 2015-11-13T17:52:00 ... 2023-0...
#     LATITUDE         (N_POINTS) float64 54.1 54.1 54.1 ... 57.02 57.02 57.02
# ...

# %%
#Special Cases

# %%
apDS = argo_loader.float(7900572).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 41539)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 41535 41536 41537 41538
#     TIME             (N_POINTS) datetime64[ns] 2020-06-30T05:48:19.990000 ......
#     LATITUDE         (N_POINTS) float64 48.97 48.97 48.97 ... 57.02 57.02 57.02
#     LONGITUDE        (N_POINTS) float64 -12.99 -12.99 -12.99 ... -21.65 -21.65
# ...

# %%
apDS = argo_loader.float(3901871).load().data
apDS = argo_loader.data
argo_loader.plot('trajectory', set_global=True)
apDS
# Out:
# C:\Users\lily\mambaforge\envs\AOS2\lib\site-packages\argopy\data_fetchers\argovis_data.py:326: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   ds['TIME'] = ds['TIME'].astype(np.datetime64)
# <xarray.Dataset>
# Dimensions:          (N_POINTS: 230168)
# Coordinates:
#   * N_POINTS         (N_POINTS) int32 0 1 2 3 4 ... 230164 230165 230166 230167
#     TIME             (N_POINTS) datetime64[ns] 2016-08-31T11:39:00 ... 2023-0...
#     LATITUDE         (N_POINTS) float64 55.41 55.41 55.41 ... 56.95 56.95 56.95
# ...
